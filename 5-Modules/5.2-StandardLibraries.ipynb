# %%
import array
arr=array.array('i', [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 6
# banana

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\DHRUVI\OneDrive\Desktop\Udemy Final\PYTHON\5-Modules

# %%
os.mkdir('test_dir')

# %%
##High level Operations on files or collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
##Data SerialiZation
import json
data={'name':'Dhruvi', 'age':21, 'city':'Ahmedabad'}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))
parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Dhruvi", "age": 21, "city": "Ahmedabad"}
# <class 'str'>
# {'name': 'Dhruvi', 'age': 21, 'city': 'Ahmedabad'}
# <class 'dict'>

# %%
##csv
import csv
with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['Name','Age','City'])
    writer.writerow(['Dhruvi',21,'Ahmedabad'])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Dhruvi', '21', 'Ahmedabad']

# %%
##datetime
from datetime import datetime,timedelta
now=datetime.now()
print(now)
yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2025-10-12 21:30:58.780236
# 2025-10-11 21:30:58.780236

# %%
##time
import time 
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1760284919.2648
# 1760284921.26533

# %%
##regular expression
import re
pattern=r'\d+'
text='There are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
